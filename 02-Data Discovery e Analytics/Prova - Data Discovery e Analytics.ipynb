# %% [markdown]
# ### Pergunta 1
#
# A ferramenta Online Analytical Processing (OLAP) surgiu da necessidade de um apoio à decisão mais intensivo e cria um ambiente de análise de dados avançado que suporta tomada de decisões, modelagem de negócios e pesquisa operacional.
#
# Nessa situação, avalie as afirmações a seguir sobre OLAP.
#
# As ferramentas OLAP surgiram juntamente com os Sistemas de Apoio à Decisão para realizarem as consultas e análises dos dados.
#
# No OLAP, as informações são armazenadas permitindo visualização por meio de diversos ângulos.
#
# A arquitetura de ferramentas OLAP oferece soluções apenas para consumo em desktop.
#
# Permite realizar cálculos e modificar os dados em suas origens.
#
#
# É correto o que se afirma em:
#
#   II, e III, apenas.
#
#   I, II e III, apenas.
#
#   II, III, e IV apenas.
#
#   **I, e II, apenas.**
# Resposta correta. As alternativa III e IV estão incorretas, pois a arquitetura OLAP oferece soluções na Web, Nuvem e Mobile e Não permite modificar os dados nas suas origens.

# %% [markdown]
# ### Pergunta 2
#
# KPI é uma sigla que vem do inglês para Key Performance Indicator, são os Indicadores-Chave de Performance. Trata-se de uma ferramenta de gestão empregada para analisar os indicadores mais importantes de um negócio ou empresa.
#
# Nessa situação, avalie as afirmações a seguir sobre KPI:
#
# Permite mensurar os resultados e gerir o desempenho;
#
# Auxilia embasar a análise crítica dos resultados obtidos;
#
# Contribuir para a melhoria contínua dos processos organizacionais;
#
# Indicadores apontam e resolvem os problemas organizacionais;
#
#
# É correto o que se afirma em:
#
#   **I, II e III, apenas.**
# Resposta Correta. A afirmação IV está incorreta. Conforme estudos sobre KPI, indicadores apontam mas não resolvem problemas! Desta forma as 3 primeiras alternativas estão corretas.
#
#   II, e III, apenas
#
#   I, e II, apenas.
#
#   II, III, e IV apenas.

# %% [markdown]
# ### Pergunta 3
#
# Abaixo temos uma imagem que representa uma impressão (print de uma tela) de um determinado conjunto de dados.
#
# Baseado nos seus conhecimentos adquiridos para um bom desenvolvimento de análises de dados, avalie as afirmações a seguir :
#
# Avaliar o conteúdo de cada uma das colunas e identificar quais hierarquias serão necessárias para posterior desenvolvimento das análises;
# Identificar quais os indicadores de performance serão utilizados na construção da história que será desenvolvida. Depois identifique quais as visões que o usuário passará a enxergar estes indicadores;
#
#
# É correto o que se afirma em:
#
#   Ambas estão incorretas.
#
#   II apenas.
#
#   **Ambas estão corretas.**
# Resposta correta. Isso mesmo. Ambas estão corretas.
#
#   I apenas.

# %% [markdown]
# ### Pergunta 4
#
# Analise as imagens abaixo apresentam dois gráficos e que estão devidamente numeradas:
#
# Assinale qual(is) gráfico(s) está(ão) adequado(s) para o tipo de análise que permita avaliar a temporalidade mensal dos dados:
#
#   Ambas estão incorretas.
#
#   **Gráfico I apenas.**
# Resposta correta. O gráfico de pizza não deve ser utilizado para análises temporais
#
#   Gráfico II apenas.
#
#   Ambas estão corretas.

# %% [markdown]
# ### Pergunta 5
#
# A imagem abaixo representa a previsão de vendas realizada através da ferramenta Tableau da fornecedora Salesforce:
#
# Nessa situação, avalie as afirmações a seguir sobre a construção deste tipo de análise:
#
# Para que ocorra a Previsão é necessário que o dado seja do tipo data com dia mês e ano completos;
# A ferramenta busca padrões sazonais a cada 12 meses de dados;
# O intervalo de previsão (confiança) padrão é de 95%, mas pode ser configurado para 90 ou 99%;
# Este recurso de Previsão também pode ser aplicado nas ferramentas Power BI e Excel, por exemplo;
#
#
# É correto o que se afirma em:
#
#   I, III, e IV, apenas.
#
#   II, e III, apenas.
#
#   **I, II, III, e IV, apenas.**
# Resposta correta. Todas estão corretas.
#
#   I, II e III, apenas.

# %% [markdown]
# ### Pergunta 6
#
# Em uma Previsão hipotética baseada em vendas, analise as imagens abaixo na sequência:
#
# Assinale Verdadeiro se foi aplicada a Cenarização e Falso caso seja outra técnica utilizada.
#
#   **Verdadeiro**
# Após analisar, foi identificado que a técnica prescritiva utilizada foi a Cenarização.
#
#   Falso

# %% [markdown]
# ### Pergunta 7
#
# Pelos tipos de conectores, é possível saber qual a característica/arquitetura onde se enquadra determinada ferramenta OLAP.
#
# Assinale a qual arquitetura OLAP ela se enquadra:
#
#   **HOLAP**
#
#   Não se pode definir apenas pela imagem
#
#   ROLAP
#
#   MOLAP

# %% [markdown]
# ### Pergunta 8
#
# Em uma determinada empresa, em torno de 40% dos dados consumidos encontram-se em planilhas que contêm dados sensíveis, produzidas semanalmente por suas unidades de negócio. Os outros 60% dos dados estão presentes em alguns bancos de dados relacionais de sistemas de produção. O tamanho da base é de moderado a pequeno, mas existe a necessidade de conformidade com normas de privacidade e confidencialidade dos dados.
#
# Para ajudar no processo de tomada de decisão a empresa adotou a solução de uma ferramenta de Self-Service de BI
#
# Nessa situação, avalie as afirmações a seguir sobre Self-service de BI:
#
# O self-service de BI permite que os usuários de negócios criem suas próprias visualizações e relatórios sem a necessidade de assistência da TI. Claro que dependendo da complexidade essa assistência poderá ser requisitada;
# As ferramentas de Self Service BI não se enquadram dentro das ferramentas OLAP;
#
#
# É correto o que se afirma em:
#
#   I e II estão corretas.
#
#   I e II estão incorretas.
#
#   II apenas.
#
#   **I apenas.**
# Resposta correta. O SSBI dá uma autonomia maior aos usuários para o seu desenvolvimento.

# %% [markdown]
# ### Pergunta 9
#
# Ao explorar um data warehouse por meio de uma ferramenta OLAP, independentemente de sua arquitetura, o analista pode executar as operações de Drill Down e Drill Up, que, respectivamente, aumentam e reduzem o nível de granularidade dos dados. Mas além destas, podemos também utilizar outras operações como Drill Accros e Drill Throught.
#
# Nessa situação, avalie as afirmações a seguir sobre operações de Drill.
#
# Incialmente a análise foi gerada no nível Município e passou para o nível Bairro. Este tipo de operação é conhecido como Drill UP;
#
# Incialmente a análise foi gerada no nível Município e passou para o nível Bairro. Este tipo de operação é conhecido como Drill Down;
#
# Incialmente a análise foi gerada no nível Município e passou para o nível País. Este tipo de operação é conhecido como Drill Accross;
#
# Incialmente a análise foi gerada no nível Município e passou para o nível Produto. Este tipo de operação é conhecido como Drill Throught;
#
#
# É correto o que se afirma em:
#
#   I, III, e IV, apenas.
#
#   **II, III, e IV, apenas.**
#
#   II, e III, apenas.
#
#   I, II e III, apenas.

# %% [markdown]
# ### Pergunta 10
#
# A análise preditiva está nos planos da sua empresa? Se ainda não está, deveria, pois essa solução trata da aplicação da tecnologia para fazer o que todo gestor gostaria, mas sozinho não é capaz: antecipar o futuro. Parece exercício de astrologia? Nem tanto, se você entender os conceitos e técnicas utilizados nesse tipo de análise.
#
# Nessa situação, avalie as afirmações a seguir sobre Análise Preditiva:
#
# I - Avaliar de forma preditiva significa tomar como referência dados do passado e do presente para, a partir deles, formular prognósticos.
#
# II - Esse tipo de análise serve para trazer respostas tanto para questões já conhecidas quanto para aquelas que você nem desconfiava que existiam.
#
#
# É correto o que se afirma em:
#
#   **Ambas estão corretas.**
# Resposta correta. Isso mesmo. Ambas estão corretas
#
#   Ambas estão erradas.
#
#   II apenas.
#
#   I apenas.

# %% [markdown]
# ### Pergunta 1
#
# Uma das principais características das ferramentas OLAP é permitir através de um relatório base, gerar outras diversas análises manipulando o Cubo.
#
# Assinale a qual movimento OLAP ela se enquadra:
#
#   **PIVOT**
# Resposta correta. Como foi girado, mudando o que era analisado em Linhas para Colunas e vice-versa, este tipo de movimento é conhecido como PIVOT.
#
#   Não se pode definir pela imagem.
#
#   SLICE
#
#   Drill Down

# %% [markdown]
# ### Pergunta 3
#
# Apesar de obedecer a uma estrutura cliente/servidor multiusuário, as ferramentas OLAP podem ser implementadas de diversas formas. Alguns autores sugerem 5 ou até mesmo 6 classificações diferentes desde a criação no início dos anos 2000. Nos nossos estudos, vimos as 4 principais: ROLAP, MOLAP, HOLAP e DOLAP, onde cada uma possui características próprias.
#
# Nessa situação, avalie as afirmações a seguir sobre Arquitetura OLAP.
#
#  ROLAP: arquitetura que permite conectar somente a bases Relacionais. Uma de suas características é aproveitar as funcionalidades inerentes do banco de dados relacional;
# MOLAP: Armazenamento dos dados em cubos dimensionais, mas que possui além de um custo alto, baixo desempenho.
# HOLAP: arquitetura que tem alto desempenho e permite conectar nas mais variadas fontes de dados, característica presente nas ferramentas Qlik, Tableau e Power BI, por exemplo;
# DOLAP: arquitetura baseada 100% em desenvolvimento via browser e que se conecta apenas em bases multidimensionais
#
#
# É correto o que se afirma em:
#
#   I, II e III, apenas.
#
#   II, III, e IV apenas.
#
#   **I, e III, apenas.**
# Resposta correta. A alternativa II está incorreta, pois a arquitetura MOLAP oferece alto desempenho na criação dos cubos OLAP e a alternativa IV, o seu ambiente é realizado na máquina do usuário com a criação de cubos, além de possibilitar conexão com as mais variadas fontes de dados.
#
#   I, e II, apenas.
